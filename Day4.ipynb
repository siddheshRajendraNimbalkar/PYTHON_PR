# %%
str1 = "Hello world"

for word in str1.split():
    for letter in word:
        print(letter)
# Out:
# H
# e
# l
# l
# o
# w
# o
# r
# l
# d

# %%
# Write a Python Program to calculate the natural logarithm of any number
import math

num = int(input("Enter the bumber: "))
print(f"{num}: {math.log(num)}")
# Out:
# 2: 0.6931471805599453

# %%
# Write a Python Program for cube sum of first n natural numbers?
num = int(input("Enter the number: "))
if num <= 0:
    print("Enter a positive number")
else :
    total = sum([i**3 for i in range(1,num+1)])
    print(f"{num}: {total}")
# Out:
# 7: 784

# %%
# Write a Python Program to find sum of array

arr = [1,2,3,4,5]
print("Using sum function: ")
print(sum(arr))

total = 0
for i in arr:
    total += i
print("Using for loop: ")
print(total)
# Out:
# Using sum function:
# 15
# Using for loop:
# 15

# %%
# Write a Python Program to find largest element in an array.

arr = [1,2,3,4,5]
print("Using max function: ")
print(max(arr))

max = arr[0]
for i in arr:
    if i > max:
        max = i
print("Using for loop: ")
print(max)
# Out:
# Using max function:
# 5
# Using for loop:
# 5

# %%
# Write a Python Program for array rotation

arr = [1,2,3,4,5]

def rotateArray(arr,a):
    if a <= 0:
        print("Enter positive number")

    return arr[a:] + arr[:a]

print(rotateArray(arr,2))
# Out:
# [3, 4, 5, 1, 2]
