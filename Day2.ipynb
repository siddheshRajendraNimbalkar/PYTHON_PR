# %%
# 1. Write a Python Program to Check Prime Number.
# 2. Write a Python Program to Print all Prime Numbers in an Interval of 1-10.
# 3.Write a Python Program to Find the Factorial of a Number.
# 4. Write a Python Program to Display the multiplication Table.

# %%
# 1. Write a Python Program to Check Prime Number.
def PrimeNumber(num):
    if num > 1:
        if num == 2:
                print(num,"is a prime number")
        else:
            for i in range(2,num+1):
                if num%i == 0:
                    print(num,"is not a prime number")
                    break
                else:
                    print(num,"is a prime number")
                    break
    else:
        print(num,"is not a prime number")

num = int(input('Enter the number: '))
PrimeNumber(num)
# Out:
# 2 is a prime number

# %%
# 2. Write a Python Program to Print all Prime Numbers in an Interval of 1-10.
def PrimeNumberInterval(start,end):
    if start < end:
        for i in range(start,end +1):
            if i > 1:
                if i == 2:
                    print(i,"is a prime number")
                else:
                    for j in range(2,i):
                        if i%j == 0:
                            print(i,"is not a prime number")
                            break
                    else:
                        print(i,"is a prime number")
            elif i == 1:
                print(1," is not prime number")
    else:
        print("start must be smaller than end")

PrimeNumberInterval(1,10)
# Out:
# 1  is not prime number
# 2 is a prime number
# 3 is a prime number
# 4 is not a prime number
# 5 is a prime number
# 6 is not a prime number
# 7 is a prime number
# 8 is not a prime number
# 9 is not a prime number
# 10 is not a prime number

# %%
# 3.Write a Python Program to Find the Factorial of a Number.
def FactorialNumber(num):
    if num < 0:
        print("Factorial not exist")
    elif num == 0:
        print("Factorial is 0")
    else:
        Factorial = num
        for i in range(1,num):
            Factorial *= i
        print("Factorial of",num,"is",Factorial)

num = int(input("Enter Number: "))
FactorialNumber(num)
# Out:
# 7 * 1
# 7 * 2
# 14 * 3
# 42 * 4
# 168 * 5
# 840 * 6
# Factorial of 7 is 5040

# %%
# 4. Write a Python Program to Display the multiplication Table.
def Table(num):
    for i in range(1,11):
        print(num,"*",i,"=",num*i)

num = int(input("Enter Number: "))
Table(num)
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
